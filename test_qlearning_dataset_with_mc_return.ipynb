# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import gym
import d4rl
from qlearning_dataset_with_mc_return import qlearning_dataset_with_mc_return, compute_mc_returns

# %%
plt.plot(compute_mc_returns(np.ones(1000)))
plt.show()

# %%
env = gym.make('halfcheetah-medium-replay-v2')
# Out:
# /home/yangz2/miniconda3/envs/pytorch/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
dataset = qlearning_dataset_with_mc_return(env)
# Out:
# 100%|██████████| 201999/201999 [00:04<00:00, 48687.52it/s]

# %%
len(dataset['terminals'])/999
# Out:
# 202.0

# %%
dataset['mc_returns'], len(dataset['mc_returns'])
# Out:
# (array([-47.72345239, -47.83327565, -48.05959936, ...,  18.25404813,
#          13.16036048,   8.13231146]),
#  200799)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20, 10))
plt.plot(dataset['mc_returns'][-5000:])  # MC returns for the last 5 episodes
plt.show()
